# %% [markdown]
# # Tuple

# %%
# Properties of tuple 

# 1. Immutable 
# 2. Heterogenous 
# 3. Sequenced (can perform indexing, slicing) 
# 4. (a,b,c) is tuple , a,b,c is also tuple in python 
# 5. it can be thought as read only list

# %%
t=(1,2,3,'cdac',(23,32),['abv','arc'])
t
# Out:
# (1, 2, 3, 'cdac', (23, 32), ['abv', 'arc'])

# %%
type(t)
# Out:
# tuple

# %%
len(t)
# Out:
# 6

# %%
# cannot modify the values in tuples 
# cannot add more values in tuple once created

# %%
t.count(2)
# Out:
# 1

# %%
t.index(2)
# Out:
# 1

# %%
# Exception to edit the tuple by using list inside tuple 
t[5]
# Out:
# ['abv', 12]

# %%
t[5][1] = 12

# %%
t
# Out:
# (1, 2, 3, 'cdac', (23, 32), ['abv', 12])

# %%
lt = [1, 2, 3, 'cdac', (23, 32), ['abv', 12]]

# %%
# lt[4][0] = 344  : will give error because we are trying to access and modify the tuple inside the list

# %%
print(t*4)
# Out:
# (1, 2, 3, 'cdac', (23, 32), ['abv', 12], 1, 2, 3, 'cdac', (23, 32), ['abv', 12], 1, 2, 3, 'cdac', (23, 32), ['abv', 12], 1, 2, 3, 'cdac', (23, 32), ['abv', 12])

# %%
print(t + t)
# Out:
# (1, 2, 3, 'cdac', (23, 32), ['abv', 12], 1, 2, 3, 'cdac', (23, 32), ['abv', 12])

# %%
# tuple with single value 
tp = ("hello",)

# %%
tp
# Out:
# ('hello',)

# %%
a,b,c = 1,2,3
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
c
# Out:
# 3

# %%
type(a)
# Out:
# int

# %%
ab = 3,2,13,45,53

# %%
type(ab)
# Out:
# tuple

# %%
# to delete entire tuple we use del 
del ab

# %%
# ab is now deleted

# %% [markdown]
# # tuple is faster than list
