# %% [markdown]
# # List

# %%
# Properties of list 
# 1. Mutable 
# 2. Ordered 
# 3. Heterogenous in nature 
# 4. Sequenced datatype 
# 5. Operations include indexing , slicing , adding, multiplying, checking for membership

# %%
l1=[1,2,3] 
type(l1)
# Out:
# list

# %%
l2 =[1,2,"ab",54.1]
l2
# Out:
# [1, 2, 'ab', 54.1]

# %%
l3 = [1,2,"ahb",43.3,[14,32]]
l3
# Out:
# [1, 2, 'ahb', 43.3, [14, 32]]

# %%
len(l3)
# Out:
# 5

# %%
# to access nested list
# 1.
ac = l3[len(l3)-1]
ac
# Out:
# [14, 32]

# %%
l = len(ac)

# %%
l
# Out:
# 2

# %%
# 2. 
b = l3[4][1]
b
# Out:
# 32

# %%
# membership operator in list 
'ahb' in l3
# Out:
# True

# %%
1 in l3
# Out:
# True

# %%
4 in l3
# Out:
# False

# %%
# Updating values in list

# %%
l3[1]='noida'
l3
# Out:
# [1, 'noida', 'ahb', 43.3, [14, 32]]

# %%
# List functions
# l3[6]=78 

# append function 
l3.append(78)
l3
# Out:
# [1, 'noida', 'ahb', 43.3, [14, 32], 78, 78, 78]

# %%
# to add more than 1 value 
# below will be added as nested list 
l3.append([43,23,13,'afh','cha'])
l3
# Out:
# [1,
#  'noida',
#  'ahb',
#  43.3,
#  [14, 32],
#  78,
#  78,
#  78,
#  [43, 23, 13, 'afh', 'cha'],
#  [43, 23, 13, 'afh', 'cha']]

# %%
# in order to add multiple values in list without being nested list 
# we use extend function 
l1.extend(['adaf','afla',323,12,53,535])
l2
# Out:
# [1, 2, 'ab', 54.1]

# %%
l1
# Out:
# [1, 2, 3, 'adaf', 'afla', 323, 12, 53, 535]

# %%
# to add values at a particular location/index 
# for this we use insert function 
# it will add it after the index
l1.insert(4,98)
l1
# Out:
# [1, 2, 3, 'adaf', 98, 98, 'afla', 323, 12, 53, 535]

# %%
# now removing the values from list 
# del function 
del l1[4]

# %%
l1
# Out:
# [1, 2, 3, 'adaf', 98, 'afla', 323, 12, 53, 535]

# %%
# to destroy/ delete entire list 
del l3

# %%
# to remove more than 1 value
del l2[1:]
l2
# Out:
# [1]

# %%
l1[1+2]
# Out:
# 'adaf'

# %%
# to remove the value itself (first occurence) 
l1.remove(53) 
l1
# Out:
# [1, 2, 3, 'adaf', 98, 'afla', 323, 12]

# %%
l1.pop() 
l1
# Out:
# [1, 2, 3, 'adaf', 98, 'afla', 323]

# %%
# can also provide index to pop function 
# pop function first returns the value and then removes it

# %%
a=l1.pop()
a
# Out:
# 323

# %%
# count function will return occurences of that element
l1.count(3)
# Out:
# 1

# %%
# index function will return the index number of the value
l1.index(1)
# Out:
# 0

# %%
l1
# Out:
# [1, 2, 3, 'adaf', 98, 'afla']

# %%
# sort function( by default ascending) 
# here it will not work because our list is heterogenous 
# but if it would have been python 2x version or below it then it would work with heterogenous 
# l1.sort()

# %%
# ll = ['a','b',1,2,3]
# ll.sort() 

# will give error

# %%
ll = ['cdot','cdac','hsra','Zzra','abc','zyra','zzra'] 
ll.sort() # it will sort the list lexicographically

# %%
ll
# Out:
# ['Zzra', 'abc', 'cdac', 'cdot', 'hsra', 'zyra', 'zzra']

# %%
# to sort in descending order 
ll.sort(reverse=True)
ll
# Out:
# ['zzra', 'zyra', 'hsra', 'cdot', 'cdac', 'abc', 'Zzra']

# %%
# reverse function will display the reverse order of the values 
ll.reverse() 
ll
# Out:
# ['zzra', 'zyra', 'hsra', 'cdot', 'cdac', 'abc', 'Zzra']

# %%
# Max function will give the Max value (but with homogenous values only in python 3x version)
max(ll)
# Out:
# 'zzra'

# %%
min(ll)
# Out:
# 'Zzra'

# %%
# sorted function will display the list in sorted way 
sorted(ll)
# Out:
# ['Zzra', 'abc', 'cdac', 'cdot', 'hsra', 'zyra', 'zzra']

# %%
lt  =[1,2,43,4,3]
sum(lt)
# Out:
# 53

# %%
print(ll*2) # print the list 2 times
# Out:
# ['zzra', 'zyra', 'hsra', 'cdot', 'cdac', 'abc', 'Zzra', 'zzra', 'zyra', 'hsra', 'cdot', 'cdac', 'abc', 'Zzra']

# %%
print(ll+lt) # concatenate the  list
# Out:
# ['zzra', 'zyra', 'hsra', 'cdot', 'cdac', 'abc', 'Zzra', 1, 2, 43, 4, 3]

# %%
# clear will remove all the elements from the list and return the empty list
