# %%
# 1. Write a python program to sum all the items in a list 

li = [1,2,3,4,5] 

total = 0 

for i in li:
    total+=i
print("Sum of all items in list: ",total)
# Out:
# Sum of all items in list:  15

# %%
# 2. Write a python program to get the largest number from the list 

li=[1,2,3,4,5] 

largest =0 ; 
for i in li: 
    if i>largest:
        largest=i
print("Largest number in list is : ",largest)
# Out:
# Largest number in list is :  5

# %%
# 3. Write a program to get the smallest number from the list
li=[1,2,3,4,5] 

smallest =0 ; 
for i in li: 
    if i>smallest:
        smallest=i
print("smallest number in list is : ",smallest)
# Out:
# smallest number in list is :  5

# %%
# 4. Write a python program to display the first and last colors from the following list
# color_list = ["Red","Green","White","Black"] 

color_list = ["Red","Green","White","Black"] 
first = color_list[0] 
last = color_list[-1] 

print("First color : ",first) 
print("Last color : ",last)
# Out:
# First color :  Red
# Last color :  Black

# %%
# 5. Write a python program to add 'ing' at the end of a given string (length should be at least 3).
# if the given string is already ends with 'ing' then add 'ly' instead 

n = int(input("Enter the length of list: "))

li = [input("Enter the string: ") for i in range(n)]


def suffixchange(st: str):
    if len(st) >= 3:
        if st[-3:] == "ing":
            st = st[:-3] + "ly"
        else:
            st = st + "ing"
    return st


for i in range(n):
    li[i] = suffixchange(li[i])

print(li)
# Out:
# Enter the length of list:  3
# Enter the string:  abcd
# Enter the string:  efgh
# Enter the string:  doing
# ['abcding', 'efghing', 'doly']

# %%
# Q6: The marks obtained by a student in 5 different Subjects are input through a keyboard. The
# Student gets a division as per the following rules.
# 1. Percentage above or equal to 60 – First Division
# 2. Percentage between 50 and 59 – Second Division
# 3. Percentage between 40 and 49 – Third Division
# 4. Percentage less than 40 – Fail


lt=[] 
for i in range(0,5,1):
    marks=int(input(f"Enter marks for {i+1} subject: "))
    if marks < 0 and marks>100:
        print("Enter marks in range 0 to 100 only")
        break
    else:
        lt.append(marks)

total = 0 
for i in range(0,5,1):
    total = total+lt[i]

percentage = int((total/500)*100)
print("Percentage : ",percentage)

if percentage >= 60:
    print("First Division")
elif percentage >=50:
    print("Second Division")
elif percentage >=40:
    print("Third Division")
else:
    print("Fail")
# Out:
# Enter marks for 1 subject:  70
# Enter marks for 2 subject:  70
# Enter marks for 3 subject:  70
# Enter marks for 4 subject:  70
# Enter marks for 5 subject:  70
# Percentage :  70
# First Division

# %%
# Q7: write a Python program to find the largest number among the three input numbers

a = int(input("Enter first number"))
b = int(input("Enter Secod number"))
c = int(input("Enter Third number"))

if a>=b:
        if a>=c:
            print("First number is largest")
        else:
            print("Third number is largest")
elif b>=c:
    print("Second number is largest")
else:
    print("Third number is largest")
# Out:
# Enter first number 3
# Enter Secod number 4
# Enter Third number 2
# Second number is largest

# %%
# Q8: Write a Python program to check if the input year is a leap year or not.

year=int(input("Enter Year : ")) 

if year%400==0:
    print("Leap Year")
elif year%100==0:
    print("Not a Leap Year")
elif year%4==0:
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter Year :  2004
# Leap Year

# %%
# 9. Write a program to check if a string is palindrome or not 
st = str(input("Enter String : ")) 

if st ==st[::-1]: 
    print("Palindrome")
else:
    print("Not a Palindrom")
# Out:
# Enter String :  madam
# Palindrome

# %%
# 10. Extend the nested list 

list1=["a","b",["c",["d","e",["f","g"],"k"],"l"],"m","n"] 

list1[2][1][2].extend(["h","i","j"]) 
print(list1)
# Out:
# ['a', 'b', ['c', ['d', 'e', ['f', 'g', 'h', 'i', 'j'], 'k'], 'l'], 'm', 'n']

# %%
# 11. Replace the first occurence of 20 with 200 

list1 = [5,10,15,20,25,50,20]

for i in range(len(list1)):
    if list1[i]==20:
        list1[i]=200
        break

print(list1)
# Out:
# [5, 10, 15, 200, 25, 50, 20]
