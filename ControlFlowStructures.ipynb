# %%
# Selection Structures (Conditional or decision making structure)
# if, elif , else , (no switch case) , match case

# %%
# iterative structures : loops in python ( for loop , while loop )

# %%
my name is anthony gunzaqbis
# Out:
#   Cell In[2], line 1
#     my name is anthony gunzaqbis
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# anddd mandd ka tola
